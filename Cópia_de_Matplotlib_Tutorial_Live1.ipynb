# %% [markdown]
# <a href="https://colab.research.google.com/github/AdrianoRAraujo365/Matplotlib_Tutorial_Live1/blob/master/C%C3%B3pia_de_Matplotlib_Tutorial_Live1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,20,1000)
y=np.sin(x)+0.2*x
plt.plot(x,y)

# %%
x=np.linspace(0,20,1000)
y=np.sin(x)+0.2*x
plt.plot(x,y)
plt.show()

# %%
x=np.linspace(0,20,1000)
y=np.sin(x)+0.2*x
plt.plot(x,y)
plt.xlabel("input")
plt.ylabel("output")
plt.title("MyPlot")
# Out:
# Text(0.5, 1.0, 'MyPlot')

# %%
#scatterplot
x=np.random.randn(100,2)
plt.scatter(x[:,0],x[:,1])

# %%
x=np.random.randn(200,2)
x[:50]+=3
y=np.zeros(200)
y[:50]=1
plt.scatter(x[:0],x[:,1], c=y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-71eef4633111> in <module>()
#       3 y=np.zeros(200)
#       4 y[:50]=1
# ----> 5 plt.scatter(x[:0],x[:,1], c=y)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
# ...

# %%
#Histograma
x=np.random.randn(10000)
plt.hist(x);
plt.hist(x,bins=50);

# %%
x=np.random.randn(10000)
plt.hist(x,bins=50);
